# %% [markdown]
# # Happiness (Assignment 1)
# ## 1) Data Quality Evaluation
#     Overall this is a decently large dataset from a generally trustworthy source. It is a widely cited set of data used in politics and many other applications to help make big decisions. One thing to watch out for is cultural bias from both how the questions are asked and how the responses are recorded.

# %%
import pandas as pd

df = pd.read_excel('DataForTable2.1WHR2023.xls')
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %%
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ### Size
#     This dataset has 2199 total lines, with 349 total missing entries across 9 data columns, or 98.237%.
# ### Features
#     Life Ladder:                      A measure of well-being, asking respondents to evaluate their life as a whole.
#                                       Represented by a number 0 - 10.
#
#     Log GDP per capita:               The GDP per capita, indicating economic prosperity.
#                                       Represented by the natural logarithm of GDP per capita.
#
#     Social support:                   The extent of social support networks and feelings of being cared for in society.
#                                       Represented by a number 0 - 1.
#
#     Healthy life expectancy at birth: Estimates the number of years a person can expect to live in good health.
#                                       Represented by the number of years.
#
#     Freedom to make life choices:     Assesses the level of autonomy individuals feel they have in making life choices.
#                                       Represented by a number 0 - 1.
#
#     Generosity:                       Looks at the average level of charitable giving and generosity in a society.
#                                       Represented by a number seemingly -1 - 1.
#
#     Perceptions of corruption:        Measures how widespread corruption is perceived to be within a country.
#                                       Represented by a number 0 - 1 where a higher number indicates more corruption.
#
#     Positive affect:                  Measures the average frequency of positive emotions or experiences.
#                                       Represented by a number 0 - 1.
#
#     Negative affect:                  Measures the average frequency of negative emotions or experiences.
#                                       Represented by a number 0 - 1 where a higher number indicates more negative affects.
# ### Missing Data
#     There are 349 total missing entries across 9 data columns. This means the data is 98.237%, however this doesn't account for years of missing data from individual countries.
#
#     Out of the years that are there, there are a few missing values for many countries, although a few have a significant amount missing.
#
# ##### Those are:
#     1) Saudi Arabia.          Missing 'perceptions of corruption' for almost every year.
#     2) China.                 Missing 'perceptions of corruption' for almost every year. Missing 'freedom to make life
#                                  choices' datapoints for several early/mid years.
#     3) Algeria.               Missing 1/3 of all datapoints in 2010, 2014, and 2016
#     4) Bahrain.               Missing some varied data, mostly 'perceptions of corruption' and almost all 2014 data.
#     5) Cuba.                  Surprisingly has some data from 2006, but is mostly missing.
#     6) Egypt.                 Missing 'perceptions of corruption' for several years, and some other missing data.
#     7) Hong Kong.             Missing 'healthy life expectancy at birth' datapoints for all years.
#     8) Jordan.                Missing 'perceptions of corruption' for most years and several other missing datapoints.
#     9) Kosovo.                Missing 'healthy life expectancy at birth'.
#     10) Kuwait.               Missing many scattered datapoints. Mostly 'perceptions of corruption'.
#     11) Malta.                Missing 'perceptions of corruption' in earlier years.
#     12) Qatar.                Missing a significant amount of data for most years.
#     13) Somaliland.           Missing 'log GDP per capita', 'healthy life expectancy at birth', and 'generosity'.
#     14) South Sudan.          Missing 'log GDP per capita' and 'generosity'.
#     15) Palestine.            Missing 'healthy life expectancy at birth'.
#     16) Taiwan.               Missing 'healthy life expectancy at birth', and 'log GDP per capita' and 'generosity' recently.
#     17) Tajikistan            Recently missing 'freedom to make life choices'.
#     18) Turkmenistan.         Missing 'perceptions of corruption'.
#     19) United Arab Emirates. Missing 'perceptions of corruption' for most years and many other datapoints.
#     20) Venezuela.            Recently missing 'log GDP per capita' and 'generosity'
#     21) Vietnam.              Missing almost all 2017 data

# %%
import seaborn as sns
import numpy as np

num_df = df.select_dtypes(include=[np.number])
sns.heatmap(num_df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Correlation
#     There are some very strong correlations as well and some seemingly overpowering features when it comes to how they affect the country's overall happiness.
#
# ##### Positive correlation
#     Features with a strong positive correlation to eachother are: 'Life Ladder', 'Log GDP per capita', 'Social support', and 'Healthy life expectancy at birth'. Two others with slightly weaker positive correlation are 'Positive affect' and 'Freedom to make life choices'.
#
#     This means that when one of these features is higher, the others are likely too, which shows that happy countries generally have higher numbers in all of these.
#
# ##### Negative correlation
#     Features with a weak to medium negative correlation to everything but eachother are: 'Perceptions of corruption' and 'Negative affect'.
#
#     This means that when these have higher values, the other features tend to have lower values, meaning when these are high the general happiness is usually lower.
#
# ##### No correlation
#     The feature 'Generosity' surprisingly doesn't have much of a correlation with anything.
#
#     This means that the happiness of a country doesn't really affect their generosity.

# %%
import matplotlib.pyplot as plt

cols = 3
rows = 4

fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(15, rows * 5))
axes = axes.flatten()

for i, col in enumerate(df.columns):
    sns.histplot(df[col], ax=axes[i], kde=True)
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.subplots_adjust(top=0.9)
plt.suptitle('Histograms of Various Features', fontsize=16)
plt.show()

# %%
df['year'].value_counts()
# Out:
# year
# 2017    147
# 2011    146
# 2014    144
# 2019    143
# 2015    142
# 2012    141
# 2016    141
# 2018    141
# 2013    136
# 2010    124
# 2021    122
# 2020    116
# 2009    114
# 2022    114
# 2008    110
# 2007    102
# 2006     89
# 2005     27
# Name: count, dtype: int64

# %% [markdown]
# ### Distribution
# Years appears to have 3 spikes, but doing value_counts() shows a more consistent result. The plot seems to be showing those bars at twice the height for some reason
#
# All others appear to have skewed but normal distributions

# %% [markdown]
# ### Improvements
#     To improve the dataset, it could be beneficial to include an objective measure of well-being, data from tracking the same individuals over time, more features such as mental health, and perhaps scores tracked by smaller regions instead of just country.
#
#     Note: apparently Life Ladder is the measure of objective well-being, whi

# %%
# Reset df between runs to not create too many columns
df = pd.read_excel('DataForTable2.1WHR2023.xls')

# Function to normalize data so features with larger scales don't outweigh the others
def min_max_normalize(column):
    min_value = np.min(column)
    max_value = np.max(column)
    normalized = (column - min_value) / (max_value - min_value)
    return normalized

# Apply normalization
for column in df.columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        if column not in ['Country name', 'year']:
            df[column + '_normalized'] = min_max_normalize(df[column])

# Function to calculate the happiness score for a row based on the normalized features, subtracting the negatively correlated
def calculate_happiness_score(row):
    positive_features = ['Life Ladder_normalized', 'Log GDP per capita_normalized', 'Social support_normalized', 
                'Healthy life expectancy at birth_normalized', 'Freedom to make life choices_normalized', 
                'Generosity_normalized', 'Positive affect_normalized']
    positive_score = row[positive_features].sum()
    
    negative_features = ['Perceptions of corruption_normalized', 'Negative affect_normalized']
    negative_score = row[negative_features].sum()
    
    score = positive_score - negative_score
    
    return score / len(positive_features)

# Calculate happiness for each row
df['Overall Happiness Score'] = df.apply(calculate_happiness_score, axis=1)

df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# ## 2) Happiest Countries
# ### Happiest Country 2022

# %%
df_2022 = df[df['year'] == 2022]
df_2022[df_2022['Overall Happiness Score'] == df_2022['Overall Happiness Score'].max()]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 521      Denmark  2022     7.544965           10.994299        0.970306
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 521                            71.375                      0.929547
#
#      Generosity  Perceptions of corruption  Positive affect  ...  \
# 521    0.224115                    0.20314          0.78682  ...
#
#      Life Ladder_normalized  Log GDP per capita_normalized  \
# 521                0.929654                       0.890911
#
#      Social support_normalized  Healthy life expectancy at birth_normalized  \
# 521                   0.977557                                     0.954247
#
#      Freedom to make life choices_normalized  Generosity_normalized  \
# 521                                 0.923547               0.539919
#
#      Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ### Happiest Country 2012

# %%
df_2012 = df[df['year'] == 2012]
df_2012[df_2012['Overall Happiness Score'] == df_2012['Overall Happiness Score'].max()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1868  Switzerland  2012     7.776209           11.107383        0.946864
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1868                         71.519997                      0.945428
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 1868    0.132033                   0.323241         0.792705  ...
#
#       Life Ladder_normalized  Log GDP per capita_normalized  \
# 1868                0.963975                       0.909337
#
#       Social support_normalized  Healthy life expectancy at birth_normalized  \
# 1868                   0.946676                                     0.956387
#
#       Freedom to make life choices_normalized  Generosity_normalized  \
# 1868                                 0.945372               0.451398
#
#       Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ### Happiest Country of All Time

# %%
df[df['Overall Happiness Score'] == df['Overall Happiness Score'].max()]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 509      Denmark  2010     7.770515           10.836152        0.974977
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 509                         69.400002                      0.943631
#
#      Generosity  Perceptions of corruption  Positive affect  ...  \
# 509    0.238271                   0.174896         0.796209  ...
#
#      Life Ladder_normalized  Log GDP per capita_normalized  \
# 509                 0.96313                       0.865141
#
#      Social support_normalized  Healthy life expectancy at birth_normalized  \
# 509                    0.98371                                     0.925098
#
#      Freedom to make life choices_normalized  Generosity_normalized  \
# 509                                 0.942902               0.553527
#
#      Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ## 3) Most Changed Happiness
#     This compares the first year of data collected for the country, to their 2022 data, which inherently excludes all countries without 2022 data.

# %%
# Filter countries without data for 2022
df_2022 = df[df['year'] == 2022]
countries_with_2022_data = df_2022['Country name'].unique()
df_filtered = df[df['Country name'].isin(countries_with_2022_data)]

# Find first year data for all countries
first_year_data = df_filtered.groupby('Country name').first().reset_index()
merged_df = pd.merge(first_year_data[['Country name', 'Overall Happiness Score']], 
                     df_2022[['Country name', 'Overall Happiness Score']], 
                     on='Country name', suffixes=('_first', '_2022'))

# Calculate change in overall happiness score
merged_df['Change in Overall Happiness'] = merged_df['Overall Happiness Score_2022'] - merged_df['Overall Happiness Score_first']

merged_df.describe()
# Out:
#        Overall Happiness Score_first  Overall Happiness Score_2022  \
# count                     114.000000                    114.000000
# mean                        0.481245                      0.506211
# std                         0.149322                      0.157294
# min                         0.145267                     -0.089616
# 25%                         0.379423                      0.395513
# 50%                         0.465727                      0.512636
# 75%                         0.576261                      0.618356
# max                         0.804394                      0.814866
#
#        Change in Overall Happiness
# count                   114.000000
# mean                      0.024966
# std                       0.101524
# min                      -0.357688
# 25%                      -0.017858
# 50%                       0.024574
# 75%                       0.090131
# max                       0.306593

# %% [markdown]
# ### Most Increased

# %%
merged_df[merged_df['Change in Overall Happiness'] == merged_df['Change in Overall Happiness'].max()]
# Out:
#    Country name  Overall Happiness Score_first  Overall Happiness Score_2022  \
# 58       Kosovo                       0.145267                      0.451861
#
#     Change in Overall Happiness
# 58                     0.306593

# %% [markdown]
# ### Most Decreased

# %%
merged_df[merged_df['Change in Overall Happiness'] == merged_df['Change in Overall Happiness'].min()]
# Out:
#   Country name  Overall Happiness Score_first  Overall Happiness Score_2022  \
# 0  Afghanistan                       0.268071                     -0.089616
#
#    Change in Overall Happiness
# 0                    -0.357688

# %% [markdown]
# # Redo 2 and 3 with Life Ladder as the Happiness Score

# %% [markdown]
# ## 2) Happiest Countries
# ### 2022

# %%
df_2022 = df[df['year'] == 2022]
df_2022[df_2022['Life Ladder'] == df_2022['Life Ladder'].max()]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 637      Finland  2022     7.728998           10.814193        0.974395
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 637                         71.224998                      0.958609
#
#      Generosity  Perceptions of corruption  Positive affect  ...  \
# 637    0.102147                   0.190207         0.741323  ...
#
#      Life Ladder_normalized  Log GDP per capita_normalized  \
# 637                0.956968                       0.861563
#
#      Social support_normalized  Healthy life expectancy at birth_normalized  \
# 637                   0.982943                                     0.952033
#
#      Freedom to make life choices_normalized  Generosity_normalized  \
# 637                                 0.963487               0.422668
#
#      Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ### 2012

# %%
df_2012 = df[df['year'] == 2012]
df_2012[df_2012['Life Ladder'] == df_2012['Life Ladder'].max()]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1868  Switzerland  2012     7.776209           11.107383        0.946864
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1868                         71.519997                      0.945428
#
#       Generosity  Perceptions of corruption  Positive affect  ...  \
# 1868    0.132033                   0.323241         0.792705  ...
#
#       Life Ladder_normalized  Log GDP per capita_normalized  \
# 1868                0.963975                       0.909337
#
#       Social support_normalized  Healthy life expectancy at birth_normalized  \
# 1868                   0.946676                                     0.956387
#
#       Freedom to make life choices_normalized  Generosity_normalized  \
# 1868                                 0.945372               0.451398
#
#       Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ### Happiest Country of All Time

# %%
df[df['Life Ladder'] == df['Life Ladder'].max()]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 505      Denmark  2005     8.018934           10.849012        0.972372
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 505                         68.300003                      0.971135
#
#      Generosity  Perceptions of corruption  Positive affect  ...  \
# 505         NaN                   0.236522         0.776689  ...
#
#      Life Ladder_normalized  Log GDP per capita_normalized  \
# 505                     1.0                       0.867237
#
#      Social support_normalized  Healthy life expectancy at birth_normalized  \
# 505                   0.980277                                     0.908863
#
#      Freedom to make life choices_normalized  Generosity_normalized  \
# 505                                 0.980701                    NaN
#
#      Perceptions of corruption_normalized  Positive affect_normalized  \
# ...

# %% [markdown]
# ## 3) Most Changed Happiness
#     This compares the first year of data collected for the country, to their 2022 data, which inherently excludes all countries without 2022 data.

# %%
# Filter countries without data for 2022
df_2022 = df[df['year'] == 2022]
countries_with_2022_data = df_2022['Country name'].unique()
df_filtered = df[df['Country name'].isin(countries_with_2022_data)]

# Find first year data for all countries
first_year_data = df_filtered.groupby('Country name').first().reset_index()
merged_df = pd.merge(first_year_data[['Country name', 'Life Ladder']], 
                     df_2022[['Country name', 'Life Ladder']], 
                     on='Country name', suffixes=('_first', '_2022'))

# Calculate change in overall happiness score
merged_df['Change in Life Ladder'] = merged_df['Life Ladder_2022'] - merged_df['Life Ladder_first']

merged_df.describe()
# Out:
#        Life Ladder_first  Life Ladder_2022  Change in Life Ladder
# count         114.000000        114.000000             114.000000
# mean            5.412299          5.585126               0.172827
# std             1.243847          1.265302               0.836477
# min             3.202429          1.281271              -3.138818
# 25%             4.428054          4.715273              -0.330903
# 50%             5.300925          5.891891               0.204659
# 75%             6.411352          6.478360               0.779032
# max             8.018934          7.728998               1.985126

# %%
merged_df.head()
# Out:
#   Country name  Life Ladder_first  Life Ladder_2022  Change in Life Ladder
# 0  Afghanistan           3.723590          1.281271              -2.442319
# 1      Albania           4.634252          5.212213               0.577961
# 2    Argentina           6.312925          6.260993              -0.051932
# 3      Armenia           4.289311          5.381943               1.092632
# 4    Australia           7.340688          7.034696              -0.305992

# %% [markdown]
# ### Most Increased

# %%
merged_df[merged_df['Change in Life Ladder'] == merged_df['Change in Life Ladder'].max()]
# Out:
#            Country name  Life Ladder_first  Life Ladder_2022  \
# 20  Congo (Brazzaville)           3.819792          5.804919
#
#     Change in Life Ladder
# 20               1.985126

# %% [markdown]
# ### Most Decreased

# %%
merged_df[merged_df['Change in Life Ladder'] == merged_df['Change in Life Ladder'].min()]
# Out:
#    Country name  Life Ladder_first  Life Ladder_2022  Change in Life Ladder
# 61      Lebanon           5.491245          2.352428              -3.138818
